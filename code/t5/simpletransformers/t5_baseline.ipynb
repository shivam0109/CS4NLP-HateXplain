# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 120.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 50.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 96.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 98.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 29.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from simpletransformers.t5 import T5Model

# %%
train_df = pd.read_csv("/content/drive/MyDrive/CS4NLP-HateXplain/data/t5_modeling/df_train.csv").astype(str)[['prefix','input_text','target_text']]
eval_df = pd.read_csv("/content/drive/MyDrive/CS4NLP-HateXplain/data/t5_modeling/df_val.csv").astype(str)[['prefix','input_text','target_text']]

# %%
model_args = {
    "max_seq_length": 196,
    "train_batch_size": 16,
    "eval_batch_size": 64,
    "num_train_epochs": 10,
    "evaluate_during_training": True,
    "evaluate_during_training_steps": 15000,
    "evaluate_during_training_verbose": True,
    "use_multiprocessing": False,
    "fp16": False,
    "save_steps": -1,
    "save_eval_checkpoints": False,
    "save_model_every_epoch": False,
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "learning_rate":1e-3,
    "weight_decay":0.01
}

# %%
model = T5Model("t5", "t5-base", args=model_args)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
model.train_model(train_df, eval_data=eval_df, output_dir="/content/drive/MyDrive/CS4NLP-HateXplain/data/t5_modeling/")
# Out:
#   0%|          | 0/56273 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3619: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ...
#   0%|          | 0/7147 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3619: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ...

# %%
from google.colab import files
# !zip -r /content/outputs.zip /content/outputs
# Out:
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/tokenizer_config.json (deflated 83%)
#   adding: content/outputs/model_args.json (deflated 63%)
#   adding: content/outputs/best_model/ (stored 0%)
#   adding: content/outputs/best_model/scheduler.pt (deflated 50%)
#   adding: content/outputs/best_model/optimizer.pt (deflated 15%)
#   adding: content/outputs/best_model/tokenizer_config.json (deflated 83%)
#   adding: content/outputs/best_model/model_args.json (deflated 63%)
#   adding: content/outputs/best_model/generation_config.json (deflated 29%)
#   adding: content/outputs/best_model/eval_results.txt (stored 0%)
#   adding: content/outputs/best_model/pytorch_model.bin (deflated 7%)
#   adding: content/outputs/best_model/special_tokens_map.json (deflated 86%)
#   adding: content/outputs/best_model/training_args.bin (deflated 50%)
#   adding: content/outputs/best_model/spiece.model (deflated 48%)
#   adding: content/outputs/best_model/config.json (deflated 62%)
# ...

# %%
model_args2 = {
    "overwrite_output_dir": True,
    "max_seq_length": 196,
    "eval_batch_size": 32,
    "use_multiprocessing": False,
    "num_beams": 1,
    "do_sample": True,
    "max_length": 50,
    "top_k": 50,
    "top_p": 0.95,
    "num_return_sequences": 3,
}

# Load the trained model
model = T5Model("t5", "/content/outputs/best_model", args=model_args2)

# %%
# Test dataset
test_df = pd.read_csv("/content/drive/MyDrive/CS4NLP-HateXplain/data/t5_modeling/df_test.csv").astype(str)[['prefix','input_text','target_text']]


# Prepare the data for testing
to_predict = [
    prefix + ": " + str(input_text)
    for prefix, input_text in zip(test_df["prefix"].tolist(), test_df["input_text"].tolist())
]
truth = test_df["target_text"].tolist()
tasks = test_df["prefix"].tolist()

# %%
# Get the model predictions
preds = model.predict(to_predict)
# Out:
# Generating outputs:   0%|          | 0/221 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3745: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, text_target=tgt_texts, ...)
#
# If you either need to use different keyword arguments for the source and target texts, you should do two calls like
# this:
#
# model_inputs = tokenizer(src_texts, ...)
# labels = tokenizer(text_target=tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# ...

# %%
## Taking only the top (first) predictions
top_preds = [pred[0] for pred in preds]
test_df["predicted"] = top_preds
test_df['all_preds'] = preds

## Saving predictions
test_df.to_csv('/content/drive/MyDrive/CS4NLP-HateXplain/data/t5_modeling/df_test_predictions_baseline.csv', index=False)

# %%
test_df.head()
# Out:
#         prefix                                         input_text  \
# 0        label  Mary Mary Mary i know it god world trump is fa...
# 1        label  in 2 there was 2 million white christian south...
# 2        label                     Albert there was no moslem ban
# 3  comm_target  laughed at i have been disrespected by all of ...
# 4  comm_target  Karen there were also no mentions of the threa...
#
#      target_text   predicted                       all_preds
# 0         normal      normal     [normal, normal, offensive]
# 1           hate        hate              [hate, hate, hate]
# 2         normal      normal     [normal, normal, offensive]
# 3    Other Asian  Asian None  [Asian None, Asian None, None]
# 4  Other Refugee        None  [None, Other Refugee, Refugee]

# %%
test_df_prefix_label = test_df[test_df['prefix']=='label'].copy()
test_df_prefix_label
# Out:
#      prefix                                         input_text target_text  \
# 0     label  Mary Mary Mary i know it god world trump is fa...      normal
# 1     label  in 2 there was 2 million white christian south...        hate
# 2     label                     Albert there was no moslem ban      normal
# 6     label             spread you bitches like a butter knife   offensive
# 7     label  i feel that i am a muslim and you whores need ...   offensive
# ...     ...                                                ...         ...
# 7023  label  o brien said that the vast majority of the 9 i...      normal
# 7024  label  me quietly sitting in class with my friend and...   offensive
# 7025  label  Christopher Christopher Christopher no one wan...      normal
# 7033  label  teacher asks class where is pakistan little jo...      normal
# 7041  label  you know those women you see around that have ...   offensive
#
#       predicted                          all_preds
# ...

# %%
exact_matches = test_df_prefix_label['target_text'].apply(lambda x: x.strip()) == test_df_prefix_label['predicted'].apply(lambda x: x.strip())
(exact_matches.sum())/(exact_matches.shape[0])
# Out:
# 0.5883021010789324

# %%
test_df_prefix_label['majority'] = test_df['all_preds'].apply(lambda x: max(set(x), key = x.count))
majority_matches = test_df_prefix_label['target_text'].apply(lambda x: x.strip()) == test_df_prefix_label['majority'].apply(lambda x: x.strip())
(majority_matches.sum())/(majority_matches.shape[0])
# Out:
# 0.6189664963089154
